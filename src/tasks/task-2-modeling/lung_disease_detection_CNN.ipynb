# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential


from tabulate import tabulate

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pathlib
dataset_dir = "drive/MyDrive/Lung Disease Detection/combined_train"

# %%
batch_size = 32
img_height = 256
img_width = 256

# %%
from numpy import testing
train_ds = tf.keras.utils.image_dataset_from_directory(
                dataset_dir,
                validation_split=0.2,
                subset="training",
                seed=123,
                image_size=(img_height, img_width),
                batch_size=batch_size)
# Out:
# Found 2935 files belonging to 4 classes.
# Using 2348 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
                dataset_dir,
                validation_split=0.2,
                subset="validation",
                seed=123,
                image_size=(img_height, img_width),
                batch_size=batch_size)
# Out:
# Found 2935 files belonging to 4 classes.
# Using 587 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['diseased_ctscan', 'diseased_xray', 'not_diseased_ctscan', 'not_diseased_xray']

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 256, 256, 3)
# (32,)

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
resize = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(img_height,img_width)
    
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
num_classes = len(class_names)

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  resize,
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_9 (Rescaling)     (None, 256, 256, 3)       0
#
#  sequential_9 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d_38 (Conv2D)          (None, 256, 256, 16)      448
#
#  max_pooling2d_38 (MaxPoolin  (None, 128, 128, 16)     0
#  g2D)
#
#  conv2d_39 (Conv2D)          (None, 128, 128, 16)      2320
#
#  max_pooling2d_39 (MaxPoolin  (None, 64, 64, 16)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 64, 64, 32)        4640
#
#  max_pooling2d_40 (MaxPoolin  (None, 32, 32, 32)       0
#  g2D)
#
#  conv2d_41 (Conv2D)          (None, 32, 32, 32)        9248
#
#  max_pooling2d_41 (MaxPoolin  (None, 16, 16, 32)       0
#  g2D)
#
#  conv2d_42 (Conv2D)          (None, 16, 16, 64)        18496
#
#  max_pooling2d_42 (MaxPoolin  (None, 8, 8, 64)         0
#  g2D)
#
#  conv2d_43 (Conv2D)          (None, 8, 8, 64)          36928
#
#  max_pooling2d_43 (MaxPoolin  (None, 4, 4, 64)         0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 4, 4, 64)          36928
#
#  max_pooling2d_44 (MaxPoolin  (None, 2, 2, 64)         0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 256)               0
#
#  dense_14 (Dense)            (None, 128)               32896
#
#  dense_15 (Dense)            (None, 4)                 516
#
# =================================================================
# Total params: 142,420
# Trainable params: 142,420
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=20
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 74/74 [==============================] - 179s 2s/step - loss: 0.8480 - accuracy: 0.5830 - val_loss: 0.5614 - val_accuracy: 0.7462
# Epoch 2/20
# 74/74 [==============================] - 107s 1s/step - loss: 0.3422 - accuracy: 0.8739 - val_loss: 0.2378 - val_accuracy: 0.8995
# Epoch 3/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.2352 - accuracy: 0.9174 - val_loss: 0.1860 - val_accuracy: 0.9319
# Epoch 4/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.1706 - accuracy: 0.9378 - val_loss: 0.1991 - val_accuracy: 0.9267
# Epoch 5/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.1641 - accuracy: 0.9451 - val_loss: 0.1359 - val_accuracy: 0.9489
# Epoch 6/20
# 74/74 [==============================] - 107s 1s/step - loss: 0.0957 - accuracy: 0.9689 - val_loss: 0.1132 - val_accuracy: 0.9591
# Epoch 7/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0745 - accuracy: 0.9719 - val_loss: 0.1249 - val_accuracy: 0.9489
# Epoch 8/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0624 - accuracy: 0.9766 - val_loss: 0.1202 - val_accuracy: 0.9574
# Epoch 9/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0483 - accuracy: 0.9791 - val_loss: 0.1860 - val_accuracy: 0.9387
# Epoch 10/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0440 - accuracy: 0.9851 - val_loss: 0.1320 - val_accuracy: 0.9642
# Epoch 11/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0406 - accuracy: 0.9872 - val_loss: 0.1295 - val_accuracy: 0.9557
# Epoch 12/20
# 74/74 [==============================] - 107s 1s/step - loss: 0.0111 - accuracy: 0.9979 - val_loss: 0.1658 - val_accuracy: 0.9608
# Epoch 13/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0450 - accuracy: 0.9855 - val_loss: 0.1789 - val_accuracy: 0.9455
# Epoch 14/20
# 74/74 [==============================] - 116s 2s/step - loss: 0.0158 - accuracy: 0.9945 - val_loss: 0.1316 - val_accuracy: 0.9659
# Epoch 15/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0197 - accuracy: 0.9923 - val_loss: 0.1382 - val_accuracy: 0.9625
# Epoch 16/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0444 - accuracy: 0.9813 - val_loss: 0.3705 - val_accuracy: 0.9029
# Epoch 17/20
# 74/74 [==============================] - 106s 1s/step - loss: 0.0429 - accuracy: 0.9855 - val_loss: 0.1265 - val_accuracy: 0.9659
# Epoch 18/20
# 74/74 [==============================] - 105s 1s/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1511 - val_accuracy: 0.9625
# Epoch 19/20
# 74/74 [==============================] - 109s 1s/step - loss: 0.0030 - accuracy: 0.9987 - val_loss: 0.1498 - val_accuracy: 0.9693
# Epoch 20/20
# 74/74 [==============================] - 136s 2s/step - loss: 0.0043 - accuracy: 0.9979 - val_loss: 0.1492 - val_accuracy: 0.9625

# %%
test_dir = "drive/MyDrive/Lung Disease Detection/combined_test"                        

classes = os.listdir("drive/MyDrive/Lung Disease Detection/combined_test")
matrix = {
    "actual_diseasedxray_pred_dieasedxray":0,      # not_diseased  tp
    "actual_diseasedxray_pred_notdieasedxray":0,      # not_diseased  tp
    "actual_diseasedxray_pred_dieasedctscan":0,      # not_diseased  tp
    "actual_diseasedxray_pred_notdieasedctscan":0,      # not_diseased  tp
    "actual_diseasedctscan_pred_dieasedctscan":0,      # not_diseased  tp
    "actual_diseasedctscan_pred_notdieasedctscan":0,      # not_diseased  tp
    "actual_diseasedctscan_pred_dieasedxray":0,      # not_diseased  tp
    "actual_diseasedctscan_pred_notdieasedxray":0,      # not_diseased  tp
    "actual_notdiseasedxray_pred_notdieasedxray":0,      # not_diseased  tp
    "actual_notdiseasedxray_pred_dieasedxray":0,      # not_diseased  tp
    "actual_notdiseasedxray_pred_dieasedctscan":0,      # not_diseased  tp
    "actual_notdiseasedxray_pred_notdieasedctscan":0,      # not_diseased  tp
    "actual_notdiseasedctscan_pred_notdieasedctscan":0,      # not_diseased  tp
    "actual_notdiseasedctscan_pred_dieasedctscan":0,      # not_diseased  tp
    "actual_notdiseasedctscan_pred_notdieasedxray":0,      # not_diseased  tp
    "actual_notdiseasedctscan_pred_dieasedxray":0      # not_diseased  tp
    
}
i, s = 0, 0
for classe in classes[::]:
    i+=1
    path = f"{test_dir}/{classe}/"
    images = os.listdir(path)[::]
    for image in images:
        img = tf.keras.utils.load_img(path+image, 
                                    target_size=(img_height, img_width))
        img_array = tf.keras.utils.img_to_array(img)
        img_array = tf.expand_dims(img_array, 0) # Create a batch

        predictions = model.predict(img_array)
        score = tf.nn.softmax(predictions[0])
        actual, predicted = classe, class_names[np.argmax(score)]
        if actual == "diseased_xray" and predicted == "diseased_xray":
            matrix["actual_diseasedxray_pred_dieasedxray"] += 1

        elif actual == "diseased_xray" and predicted == "not_diseased_xray":
            matrix["actual_diseasedxray_pred_notdieasedxray"] += 1

        elif actual == "diseased_xray" and predicted == "diseased_ctscan":
            matrix["actual_diseasedxray_pred_dieasedctscan"] += 1

        elif actual == "diseased_xray" and predicted == "not_diseased_ctscan":
            matrix["actual_diseasedxray_pred_notdieasedctscan"] += 1

        elif actual == "diseased_ctscan" and predicted == "diseased_ctscan":
            matrix["actual_diseasedctscan_pred_dieasedctscan"] += 1

        elif actual == "diseased_ctscan" and predicted == "not_diseased_ctscan":
            matrix["actual_diseasedctscan_pred_notdieasedctscan"] += 1

        elif actual == "diseased_ctscan" and predicted == "diseased_xray":
            matrix["actual_diseasedctscan_pred_dieasedxray"] += 1

        elif actual == "diseased_ctscan" and predicted == "not_diseased_xray":
            matrix["actual_diseasedctscan_pred_notdieasedxray"] += 1

        elif actual == "not_diseased_xray" and predicted == "not_diseased_xray":
            matrix["actual_notdiseasedxray_pred_notdieasedxray"] += 1

        elif actual == "not_diseased_xray" and predicted == "diseased_xray":
            matrix["actual_notdiseasedxray_pred_dieasedxray"] += 1

        elif actual == "not_diseased_xray" and predicted == "diseased_ctscan":
            matrix["actual_notdiseasedxray_pred_dieasedctscan"] += 1

        elif actual == "not_diseased_xray" and predicted == "not_diseased_ctscan":
            matrix["actual_notdiseasedxray_pred_notdieasedctscan"] += 1

        elif actual == "not_diseased_ctscan" and predicted == "not_diseased_ctscan":
            matrix["actual_notdiseasedctscan_pred_notdieasedctscan"] += 1

        elif actual == "not_diseased_ctscan" and predicted == "diseased_ctscan":
            matrix["actual_notdiseasedctscan_pred_dieasedctscan"] += 1

        elif actual == "not_diseased_ctscan" and predicted == "not_diseased_xray":
            matrix["actual_notdiseasedctscan_pred_notdieasedxray"] += 1

        elif actual == "not_diseased_ctscan" and predicted == "diseased_xray":
            matrix["actual_notdiseasedctscan_pred_dieasedxray"] += 1
     

        if s%100 == 0:
            print(f"{round(s*100/len(os.listdir(test_dir)))}%")
        s +=1
        
        print(
           " prediction: {} and ground truth {} : {:.2f} ."
           .format(class_names[np.argmax(score)], classe, 100 * np.max(score)))
# Out:
# 0%
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.41 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 45.88 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.16 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 27.67 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.45 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 40.89 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 33.94 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.47 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.51 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 38.48 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 31.94 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_xray : 35.06 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.50 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 41.55 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.06 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.73 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 38.24 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 46.75 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 42.79 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 42.56 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 36.29 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 41.06 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 47.41 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 45.40 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.39 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 38.63 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.07 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 45.89 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.93 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 44.14 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 32.29 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 45.82 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 46.64 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 42.03 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 40.50 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.07 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 45.76 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 44.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.39 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 47.28 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.57 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 43.22 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 33.01 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 42.55 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 42.55 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 47.12 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 39.97 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.15 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 46.38 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 44.51 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.43 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 45.62 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.45 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.41 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.46 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.44 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 36.12 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 44.68 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 35.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.38 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.38 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.49 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 45.88 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.79 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.88 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 42.80 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 44.33 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 45.37 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 33.74 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.49 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.36 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 34.19 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.32 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.11 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 31.22 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 35.86 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.40 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 38.27 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
# 2500%
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 42.93 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.37 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 43.38 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 40.47 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.48 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 42.87 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.98 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.48 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.37 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.38 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.42 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 36.37 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 42.80 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.39 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 39.99 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 36.57 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 44.57 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 31.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.25 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.32 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.64 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 33.30 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 41.26 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 39.25 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.42 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 36.44 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 45.85 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.31 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.46 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.46 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 45.49 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 41.45 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.10 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 43.82 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 39.96 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.51 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.40 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.40 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 38.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.17 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.51 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 35.80 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.36 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 31.72 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.51 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 33.93 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 33.57 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.12 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.49 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.40 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.45 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
# 5000%
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.66 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 40.70 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.50 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 39.10 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 44.13 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.43 .
#  prediction: diseased_ctscan and ground truth not_diseased_xray : 32.50 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.50 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.51 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 35.78 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 43.27 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 46.89 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 41.09 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 36.49 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.41 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 36.87 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.95 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.44 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 46.51 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.50 .
#  prediction: diseased_xray and ground truth not_diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 30.54 .
#  prediction: not_diseased_xray and ground truth not_diseased_xray : 47.35 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.15 .
#  prediction: diseased_xray and ground truth diseased_xray : 43.94 .
#  prediction: diseased_xray and ground truth diseased_xray : 36.93 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_xray : 47.39 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.51 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 37.12 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.87 .
#  prediction: diseased_xray and ground truth diseased_xray : 34.79 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 37.51 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_xray : 44.88 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.26 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
# 7500%
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.51 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth diseased_xray : 46.48 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.13 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.38 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: not_diseased_xray and ground truth diseased_xray : 47.47 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.52 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.25 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.18 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.42 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
# 10000%
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.94 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.21 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.32 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.32 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 45.84 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.45 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 34.49 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.51 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.49 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 46.61 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.26 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.52 .
#  prediction: not_diseased_xray and ground truth diseased_xray : 35.55 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 45.72 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 36.47 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.50 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
# 12500%
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 36.77 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 45.40 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.48 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 42.21 .
#  prediction: diseased_xray and ground truth diseased_xray : 44.56 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 38.07 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.43 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: not_diseased_xray and ground truth diseased_xray : 47.48 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 44.01 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
# 15000%
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.33 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.53 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.50 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 45.72 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_xray and ground truth diseased_xray : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 31.56 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 46.34 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 40.52 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 44.44 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.45 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 39.02 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.52 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.20 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.50 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.42 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 45.03 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 44.87 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.49 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 46.60 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 39.33 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.51 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.39 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.52 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.10 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.52 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
# 17500%
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth diseased_ctscan : 47.53 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: diseased_ctscan and ground truth diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.15 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.47 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.52 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.51 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.17 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.51 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.51 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.15 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.53 .
#  prediction: not_diseased_ctscan and ground truth not_diseased_ctscan : 47.54 .

# %%
matrix
# Out:
# {'actual_diseasedctscan_pred_dieasedctscan': 60,
#  'actual_diseasedctscan_pred_dieasedxray': 0,
#  'actual_diseasedctscan_pred_notdieasedctscan': 24,
#  'actual_diseasedctscan_pred_notdieasedxray': 0,
#  'actual_diseasedxray_pred_dieasedctscan': 2,
#  'actual_diseasedxray_pred_dieasedxray': 384,
#  'actual_diseasedxray_pred_notdieasedctscan': 0,
#  'actual_diseasedxray_pred_notdieasedxray': 4,
#  'actual_notdiseasedctscan_pred_dieasedctscan': 0,
#  'actual_notdiseasedctscan_pred_dieasedxray': 0,
#  'actual_notdiseasedctscan_pred_notdieasedctscan': 84,
#  'actual_notdiseasedctscan_pred_notdieasedxray': 0,
#  'actual_notdiseasedxray_pred_dieasedctscan': 26,
#  'actual_notdiseasedxray_pred_dieasedxray': 125,
#  'actual_notdiseasedxray_pred_notdieasedctscan': 1,
#  'actual_notdiseasedxray_pred_notdieasedxray': 82}

# %%
table = [
         ["x", "not_diseased_xray_pred", "diseased_xray_pred","not_diseased_ctscan_pred","diseased_ctscan_pred"],
         ["not_diseased_xray_actual", f"{matrix['actual_notdiseasedxray_pred_notdieasedxray']}",f"{matrix['actual_notdiseasedxray_pred_dieasedxray']}",f"{matrix['actual_notdiseasedxray_pred_notdieasedctscan']}",f"{matrix['actual_notdiseasedxray_pred_dieasedctscan']}"],
         ["diseased_xray_actual", f"{matrix['actual_diseasedxray_pred_notdieasedxray']}",f"{matrix['actual_diseasedxray_pred_dieasedxray']}",f"{matrix['actual_diseasedxray_pred_notdieasedctscan']}",f"{matrix['actual_diseasedxray_pred_dieasedctscan']}"],
         ["not_diseased_ctscan_actual", f"{matrix['actual_notdiseasedctscan_pred_notdieasedxray']}",f"{matrix['actual_notdiseasedctscan_pred_dieasedxray']}",f"{matrix['actual_notdiseasedctscan_pred_notdieasedctscan']}",f"{matrix['actual_notdiseasedctscan_pred_dieasedctscan']}"],
         ["diseased_ctscan_actual", f"{matrix['actual_diseasedctscan_pred_notdieasedxray']}",f"{matrix['actual_diseasedctscan_pred_dieasedxray']}",f"{matrix['actual_diseasedctscan_pred_notdieasedctscan']}",f"{matrix['actual_diseasedctscan_pred_dieasedctscan']}"]
]
print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'))
# Out:
# ╒════════════════════════════╤══════════════════════════╤══════════════════════╤════════════════════════════╤════════════════════════╕
# │ x                          │   not_diseased_xray_pred │   diseased_xray_pred │   not_diseased_ctscan_pred │   diseased_ctscan_pred │
# ╞════════════════════════════╪══════════════════════════╪══════════════════════╪════════════════════════════╪════════════════════════╡
# │ not_diseased_xray_actual   │                       82 │                  125 │                          1 │                     26 │
# ├────────────────────────────┼──────────────────────────┼──────────────────────┼────────────────────────────┼────────────────────────┤
# │ diseased_xray_actual       │                        4 │                  384 │                          0 │                      2 │
# ├────────────────────────────┼──────────────────────────┼──────────────────────┼────────────────────────────┼────────────────────────┤
# │ not_diseased_ctscan_actual │                        0 │                    0 │                         84 │                      0 │
# ├────────────────────────────┼──────────────────────────┼──────────────────────┼────────────────────────────┼────────────────────────┤
# │ diseased_ctscan_actual     │                        0 │                    0 │                         24 │                     60 │
# ╘════════════════════════════╧══════════════════════════╧══════════════════════╧════════════════════════════╧════════════════════════╛
